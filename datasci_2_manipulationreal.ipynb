# %% [markdown]
# <a href="https://colab.research.google.com/github/jesschannn/datasci_2_manipulation/blob/main/datasci_2_manipulationreal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Cleaning with Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('healthcare_data_cleaning.csv')
df
# Out:
#        Patient Age  Gender  City of Residence State of Residence  \
# 0               45   Other         West Brian           Kentucky
# 1               25  Female   East Jocelynfurt           Colorado
# 2               51   Other  South Lindseyland               Ohio
# 3               18  Female         Taylorfort       Pennsylvania
# 4               48  Female          Birdmouth            Montana
# ...            ...     ...                ...                ...
# 104995          74   Other       West Anthony           Oklahoma
# 104996          37    Male          Mckeetown               Utah
# 104997          51  Female   Lake Lisachester           Nebraska
# 104998     missing  Female       Heidiborough            missing
# 104999          45  Female      South Jeffrey      Massachusetts
#
#        Has Insurance Visited Last Month Payment Method Preferred Doctor  \
# 0                Yes                Yes      Insurance     Dr. Williams
# ...

# %% [markdown]
# ## Removing Duplicates

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#        Patient Age  Gender  City of Residence State of Residence  \
# 0               45   Other         West Brian           Kentucky
# 1               25  Female   East Jocelynfurt           Colorado
# 2               51   Other  South Lindseyland               Ohio
# 3               18  Female         Taylorfort       Pennsylvania
# 4               48  Female          Birdmouth            Montana
# ...            ...     ...                ...                ...
# 104994          53  Female      Michelleburgh       South Dakota
# 104995          74   Other       West Anthony           Oklahoma
# 104996          37    Male          Mckeetown               Utah
# 104997          51  Female   Lake Lisachester           Nebraska
# 104998     missing  Female       Heidiborough            missing
#
#        Has Insurance Visited Last Month Payment Method Preferred Doctor  \
# 0                Yes                Yes      Insurance     Dr. Williams
# ...

# %% [markdown]
# ## Removed White Space and Special Characters

# %%
import pandas as pd
import re
import numpy as np

# %%
# Function to remove white space and special characters from a value
def clean_column_names(df):
    # Define a helper function to clean column names
    def clean_name(name):
        cleaned_name = re.sub(r'[^a-zA-Z0-9]', '', name)
        return cleaned_name.lower()

    # Rename columns using the helper function
    # This is using a list comprehend - e.g., we have a list to the right of the equals sign,
    # and inside the list, we are applying our function, for every col (or X) that exists in df.columns
    df.columns = [clean_name(col) for col in df.columns]
    return df

# Apply the clean_value function to all columns
df = clean_column_names(df)

df
# Out:
#        patientage  gender    cityofresidence stateofresidence hasinsurance  \
# 0              45   Other         West Brian         Kentucky          Yes
# 1              25  Female   East Jocelynfurt         Colorado           No
# 2              51   Other  South Lindseyland             Ohio          Yes
# 3              18  Female         Taylorfort     Pennsylvania          Yes
# 4              48  Female          Birdmouth          Montana           No
# ...           ...     ...                ...              ...          ...
# 104994         53  Female      Michelleburgh     South Dakota           No
# 104995         74   Other       West Anthony         Oklahoma          Yes
# 104996         37    Male          Mckeetown             Utah          Yes
# 104997         51  Female   Lake Lisachester         Nebraska          Yes
# 104998    missing  Female       Heidiborough          missing          Yes
#
# ...

# %% [markdown]
# ## Changing "Missing" to "NaN"

# %%
import re
import numpy as np

# %%
df['paymentdue'] = pd.to_numeric(df['paymentdue'], errors='coerce')
df['prescriptioncost'] = pd.to_numeric(df['prescriptioncost'], errors='coerce')

# %%
df['patientage'] = pd.to_numeric(df['patientage'], errors='coerce')
df['averageheartrate'] = pd.to_numeric(df['averageheartrate'], errors='coerce')
df['averagebp'] = pd.to_numeric(df['averagebp'], errors='coerce')
df['weightinkg'] = pd.to_numeric(df['weightinkg'], errors='coerce')
df['heightincm'] = pd.to_numeric(df['heightincm'], errors ='coerce')

# %%
df['lastvisitdaysago'] = pd.to_numeric(df['lastvisitdaysago'], errors='coerce')
df['visitdurationmins'] = pd.to_numeric(df['visitdurationmins'], errors='coerce')
df['numberoftests'] = pd.to_numeric(df['numberoftests'], errors = 'coerce')

# %% [markdown]
# ## Handling Missing Values

# %%
print(df['gender'].value_counts())
# Out:
# gender
# Male       31728
# Female     31674
# Other      31598
# missing     5000
# Name: count, dtype: int64

# %%
print(df['cityofresidence'].value_counts())
# Out:
# cityofresidence
# missing              5000
# Lake Michael          100
# West Michael           82
# East Michael           77
# Port Michael           74
#                      ...
# Deleontown              1
# Lake Hollychester       1
# Port Edwardhaven        1
# West Pamelaton          1
# Mckeetown               1
# Name: count, Length: 37133, dtype: int64

# %%
print(df['stateofresidence'].value_counts())
# Out:
# stateofresidence
# missing           5000
# New Mexico        1969
# Nevada            1969
# Idaho             1965
# Massachusetts     1959
# California        1952
# Ohio              1950
# Connecticut       1950
# Kentucky          1946
# North Carolina    1944
# New Jersey        1932
# Alaska            1927
# Wisconsin         1926
# Nebraska          1922
# Rhode Island      1918
# Minnesota         1918
# Wyoming           1917
# West Virginia     1916
# Arizona           1915
# Tennessee         1914
# South Carolina    1912
# North Dakota      1911
# Virginia          1911
# Utah              1910
# Kansas            1909
# Pennsylvania      1908
# Missouri          1906
# Iowa              1906
# Montana           1904
# Mississippi       1897
# Florida           1893
# Louisiana         1893
# Illinois          1891
# New York          1891
# Oregon            1888
# Indiana           1886
# Vermont           1885
# Texas             1876
# Oklahoma          1876
# ...

# %%
print(df['hasinsurance'].value_counts())
# Out:
# hasinsurance
# Yes        47597
# No         47403
# missing     5000
# Name: count, dtype: int64

# %%
print(df['visitedlastmonth'].value_counts())
# Out:
# visitedlastmonth
# No         47572
# Yes        47428
# missing     5000
# Name: count, dtype: int64

# %%
print(df['paymentmethod'].value_counts())
# Out:
# paymentmethod
# Card         31744
# Insurance    31662
# Cash         31594
# missing       5000
# Name: count, dtype: int64

# %%
print(df['preferreddoctor'].value_counts())
# Out:
# preferreddoctor
# Dr. Jones       19153
# Dr. Williams    19078
# Dr. Johnson     19005
# Dr. Smith       18914
# Dr. Brown       18850
# missing          5000
# Name: count, dtype: int64

# %%
print(df['diseasediagnosed'].value_counts())
# Out:
# diseasediagnosed
# Flu         19123
# Allergy     19063
# Cold        18962
# Covid-19    18831
# missing      5000
# Name: count, dtype: int64

# %%
print(df['medicationprescribed'].value_counts())
# Out:
# medicationprescribed
# Med_C      19149
# Med_D      19040
# Med_B      19003
# Med_A      18957
# Med_E      18851
# missing     5000
# Name: count, dtype: int64

# %%
print(df['typeofappointment'].value_counts())
# Out:
# typeofappointment
# Specialist    23841
# Follow-Up     23832
# Emergency     23737
# General       23590
# missing        5000
# Name: count, dtype: int64

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# patientage               5000
# gender                      0
# cityofresidence             0
# stateofresidence            0
# hasinsurance                0
# visitedlastmonth            0
# paymentmethod               0
# preferreddoctor             0
# diseasediagnosed        19021
# medicationprescribed        0
# typeofappointment           0
# averageheartrate         5000
# averagebp                5000
# heightincm               5000
# weightinkg               5000
# paymentdue               5000
# lastvisitdaysago         5000
# visitdurationmins        5000
# numberoftests            5000
# prescriptioncost         5000
# dtype: int64

# %% [markdown]
# All of the missing values in the code directly above should show 0. In the rows that show "0" in the code directly above, additional coding was ran to show that the missing values should be "5000" instead of "0".

# %% [markdown]
# ## Summary of Changes Made to the Dataset
#
# After loading the dataset into Google Colab, I removed the duplicates first. Removing the duplicates brought the amount of records / rows down from 10,500 to 10,000. Then I removed white space and special characters from the dataset. After that, I identified and handled missing values in the dataset. I noticed that all 20 columns had missing data. I decided to split the columns up based on the datatype of each column. Some columns had strings and some had floats and integers. Lastly, I cleaned the column names. In the original dataset, there were white spaces in the column names. There are now underscore characters where the white spaces used to be.

# %% [markdown]
# # Data Transformation

# %% [markdown]
# ## Creating / Renaming Columns

# %%
df.rename(columns = {'patientage':'age', 'cityofresidence': 'city', 'stateofresidence': 'state', 'diseasediagnosed':'diagnosis', 'medicationprescribed': 'prescription', 'heightinkg': 'height_cm', 'weightinkg':'weight_kg'}, inplace = True)
df
# Out:
#          age  gender               city         state hasinsurance  \
# 0       45.0   Other         West Brian      Kentucky          Yes
# 1       25.0  Female   East Jocelynfurt      Colorado           No
# 2       51.0   Other  South Lindseyland          Ohio          Yes
# 3       18.0  Female         Taylorfort  Pennsylvania          Yes
# 4       48.0  Female          Birdmouth       Montana           No
# ...      ...     ...                ...           ...          ...
# 104994  53.0  Female      Michelleburgh  South Dakota           No
# 104995  74.0   Other       West Anthony      Oklahoma          Yes
# 104996  37.0    Male          Mckeetown          Utah          Yes
# 104997  51.0  Female   Lake Lisachester      Nebraska          Yes
# 104998   NaN  Female       Heidiborough       missing          Yes
#
#        visitedlastmonth paymentmethod preferreddoctor diagnosis prescription  \
# 0                   Yes     Insurance    Dr. Williams       Flu        Med_E
# ...

# %% [markdown]
# ## Groupby and Summary Statistics

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# Flu         19123
# Allergy     19063
# Cold        18962
# Covid-19    18831
# missing      5000
# Name: count, dtype: int64

# %%
grouped_data = df.groupby('diagnosis').agg({
    'paymentdue': 'mean'
})
print(grouped_data)
# Out:
#            paymentdue
# diagnosis
# Allergy    249.602752
# Cold       249.469804
# Covid-19   250.307367
# Flu        248.349807
# missing    251.116985

# %% [markdown]
# ## Pivot Tables

# %%
pivot_data1 = df.pivot_table(index='state', columns='diagnosis', values='paymentdue', aggfunc='mean')
pivot_data1
# Out:
# diagnosis          Allergy        Cold    Covid-19         Flu     missing
# state
# Alabama         258.475924  253.521433  241.861205  258.805817  268.459983
# Alaska          249.719469  247.165292  252.916563  251.322706  253.850818
# Arizona         236.639064  241.384451  271.652943  240.353982  251.595196
# Arkansas        252.561727  254.809133  252.827011  234.717864  219.159342
# California      237.629954  252.320108  247.106517  249.626363  219.740984
# Colorado        250.340971  253.977253  242.017020  253.542667  243.588683
# Connecticut     242.163048  249.793253  251.117117  255.515563  242.848068
# Delaware        257.395008  255.363760  254.380038  242.244313  273.158737
# Florida         242.532911  261.687747  257.000379  244.405773  247.370245
# Georgia         241.569409  254.153445  247.032223  248.302253  233.869268
# Hawaii          252.464576  251.724964  251.335605  254.314797  246.972939
# ...

# %%
pivot_data2 = df.pivot_table(index='prescription', columns='paymentmethod', values='prescriptioncost', aggfunc='mean')
pivot_data2
# Out:
# paymentmethod       Card       Cash  Insurance    missing
# prescription
# Med_A          74.795720  75.606269  75.747028  74.823713
# Med_B          74.987627  73.949080  74.037480  73.032705
# Med_C          75.335473  75.818731  74.901430  75.354923
# Med_D          73.636196  74.644242  74.816745  74.907061
# Med_E          74.528966  75.317342  74.702548  75.488570
# missing        75.735100  75.032899  75.499954  72.573091

# %%
pivot_data3 = df.pivot_table(index='preferreddoctor', columns='typeofappointment', values='lastvisitdaysago', aggfunc='median')
pivot_data3
# Out:
# typeofappointment  Emergency  Follow-Up  General  Specialist  missing
# preferreddoctor
# Dr. Brown              183.0      182.0    182.0       182.0    182.0
# Dr. Johnson            183.0      182.0    182.0       183.0    182.0
# Dr. Jones              183.0      183.0    183.0       183.0    183.0
# Dr. Smith              183.0      182.0    183.0       182.0    183.0
# Dr. Williams           183.0      183.0    183.0       182.0    183.0
# missing                182.0      182.0    182.0       183.0    183.0

# %% [markdown]
# # Introduction to Alternative Libraries

# %% [markdown]
# ##Polars

# %%
pip install polars

# %%
import polars as pl

df = pl.read_csv("healthcare_data_cleaning.csv")

print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 105000
# Number of columns: 20

# %%
import time

# %%
dataset_path = 'healthcare_data_cleaning.csv'

# %%
start_time = time.time()
polars_df = pd.read_csv(dataset_path)
polars_filtered = polars_df[polars_df['Gender'] == 'Female']
polars_average_age = polars_filtered['Average Heart Rate'].sum()
polars_time = time.time() - start_time

# %% [markdown]
# ## Modin

# %%
pip install "modin[all]"

# %%
pip install --upgrade pandas

# %%
pip install --upgrade modin

# %%
pip install botocore

# %%
pip install -U modin

# %%
import os
os.kill(os.getpid(), 9)

# %%
import modin.pandas as mpd
import pandas as pd
import time

# %%
dataset_path = 'healthcare_data_cleaning.csv'

# %% [markdown]
# ## Load Times

# %%
start_time = time.time()
modin_df = mpd.read_csv(dataset_path)
modin_filtered = modin_df[modin_df['Gender'] == 'Female']
modin_average_age = modin_filtered['Average Heart Rate'].sum()
modin_time = time.time() - start_time

# %%
print(f"Modin Execution Time: {modin_time:.4f} seconds")
print(f"Polars Execution Time: {polars_time:.4f} seconds")
# Out:
# Modin Execution Time: 1.8929 seconds
# Polars Execution Time: 0.2939 seconds

# %% [markdown]
# ### Load Times Observation
#
# I noticed that the execution time for Polars was quicker than Modin by approximately 1.6 seconds. Modin took almost 2 seconds, whereas Polars took less than a second.
