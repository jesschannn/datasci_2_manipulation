# %% [markdown]
# <a href="https://colab.research.google.com/github/jesschannn/datasci_2_manipulation/blob/main/datasci_2_manipulationreal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Cleaning with Pandas

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('healthcare_data_cleaning.csv')
df
# Out:
#        Patient Age  Gender  City of Residence State of Residence  \
# 0               45   Other         West Brian           Kentucky
# 1               25  Female   East Jocelynfurt           Colorado
# 2               51   Other  South Lindseyland               Ohio
# 3               18  Female         Taylorfort       Pennsylvania
# 4               48  Female          Birdmouth            Montana
# ...            ...     ...                ...                ...
# 104995          74   Other       West Anthony           Oklahoma
# 104996          37    Male          Mckeetown               Utah
# 104997          51  Female   Lake Lisachester           Nebraska
# 104998     missing  Female       Heidiborough            missing
# 104999          45  Female      South Jeffrey      Massachusetts
#
#        Has Insurance Visited Last Month Payment Method Preferred Doctor  \
# 0                Yes                Yes      Insurance     Dr. Williams
# ...

# %% [markdown]
# ## Changing "Missing" to "NaN"

# %%
df.replace('missing', pd.np.nan, inplace=True)
df
# Out:
# <ipython-input-28-31a068059994>:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   df.replace('missing', pd.np.nan, inplace=True)
#        Patient Age  Gender  City of Residence State of Residence  \
# 0               45   Other         West Brian           Kentucky
# 1               25  Female   East Jocelynfurt           Colorado
# 2               51   Other  South Lindseyland               Ohio
# 3               18  Female         Taylorfort       Pennsylvania
# 4               48  Female          Birdmouth            Montana
# ...            ...     ...                ...                ...
# 104995          74   Other       West Anthony           Oklahoma
# 104996          37    Male          Mckeetown               Utah
# 104997          51  Female   Lake Lisachester           Nebraska
# 104998         NaN  Female       Heidiborough                NaN
# ...

# %% [markdown]
# ## Removing Duplicates

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#        Patient Age  Gender  City of Residence State of Residence  \
# 0               45   Other         West Brian           Kentucky
# 1               25  Female   East Jocelynfurt           Colorado
# 2               51   Other  South Lindseyland               Ohio
# 3               18  Female         Taylorfort       Pennsylvania
# 4               48  Female          Birdmouth            Montana
# ...            ...     ...                ...                ...
# 104994          53  Female      Michelleburgh       South Dakota
# 104995          74   Other       West Anthony           Oklahoma
# 104996          37    Male          Mckeetown               Utah
# 104997          51  Female   Lake Lisachester           Nebraska
# 104998         NaN  Female       Heidiborough                NaN
#
#        Has Insurance Visited Last Month Payment Method Preferred Doctor  \
# 0                Yes                Yes      Insurance     Dr. Williams
# ...

# %% [markdown]
# ## Removed White Space and Special Characters

# %%
import pandas as pd
import re
import numpy as np

# %%
# Function to remove white space and special characters from a value
def clean_column_names(df1):
    # Define a helper function to clean column names
    def clean_name(name):
        cleaned_name = re.sub(r'[^a-zA-Z0-9]', '', name)
        return cleaned_name.lower()

    # Rename columns using the helper function
    # This is using a list comprehend - e.g., we have a list to the right of the equals sign,
    # and inside the list, we are applying our function, for every col (or X) that exists in df.columns
    df1.columns = [clean_name(col) for col in df1.columns]
    return df

# Apply the clean_value function to all columns
df1 = clean_column_names(df)

df1
# Out:
#        patientage  gender    cityofresidence stateofresidence hasinsurance  \
# 0              45   Other         West Brian         Kentucky          Yes
# 1              25  Female   East Jocelynfurt         Colorado           No
# 2              51   Other  South Lindseyland             Ohio          Yes
# 3              18  Female         Taylorfort     Pennsylvania          Yes
# 4              48  Female          Birdmouth          Montana           No
# ...           ...     ...                ...              ...          ...
# 104994         53  Female      Michelleburgh     South Dakota           No
# 104995         74   Other       West Anthony         Oklahoma          Yes
# 104996         37    Male          Mckeetown             Utah          Yes
# 104997         51  Female   Lake Lisachester         Nebraska          Yes
# 104998        NaN  Female       Heidiborough              NaN          Yes
#
# ...

# %% [markdown]
# ## Handling Missing Values

# %%
import re
import numpy as np

# %%
df['paymentdue'] = pd.to_numeric(df['paymentdue'], errors='coerce')
df['prescriptioncost'] = pd.to_numeric(df['prescriptioncost'], errors='coerce')

# %%
df['patientage'] = pd.to_numeric(df['patientage'], errors='coerce')
df['averageheartrate'] = pd.to_numeric(df['averageheartrate'], errors='coerce')
df['averagebp'] = pd.to_numeric(df['averagebp'], errors='coerce')
df['weightinkg'] = pd.to_numeric(df['weightinkg'], errors='coerce')
df['heightincm'] = pd.to_numeric(df['heightincm'], errors ='coerce')

# %%
df['lastvisitdaysago'] = pd.to_numeric(df['lastvisitdaysago'], errors='coerce')
df['visitdurationmins'] = pd.to_numeric(df['visitdurationmins'], errors='coerce')
df['numberoftests'] = pd.to_numeric(df['numberoftests'], errors = 'coerce')

# %%
df1=df.dropna()
df1
# Out:
#         patientage  gender   cityofresidence stateofresidence hasinsurance  \
# 0             45.0   Other        West Brian         Kentucky          Yes
# 4             48.0  Female         Birdmouth          Montana           No
# 7             52.0    Male      Vanessaburgh      Connecticut          Yes
# 8             20.0  Female  West Briannabury          Montana           No
# 11            40.0  Female        Jonesmouth     Rhode Island           No
# ...            ...     ...               ...              ...          ...
# 104992        44.0  Female    Port Tracistad           Alaska          Yes
# 104993        42.0  Female     West Annaport          Florida          Yes
# 104994        53.0  Female     Michelleburgh     South Dakota           No
# 104995        74.0   Other      West Anthony         Oklahoma          Yes
# 104997        51.0  Female  Lake Lisachester         Nebraska          Yes
#
# ...

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# patientage              5000
# gender                  5000
# cityofresidence         5000
# stateofresidence        5000
# hasinsurance            5000
# visitedlastmonth        5000
# paymentmethod           5000
# preferreddoctor         5000
# diseasediagnosed        5000
# medicationprescribed    5000
# typeofappointment       5000
# averageheartrate        5000
# averagebp               5000
# heightincm              5000
# weightinkg              5000
# paymentdue              5000
# lastvisitdaysago        5000
# visitdurationmins       5000
# numberoftests           5000
# prescriptioncost        5000
# dtype: int64

# %% [markdown]
# ## Summary of Changes Made to the Dataset
#
# After loading the dataset into Google Colab, I changed all of the "missing" data into NaN. Then I removed the duplicates. Removing the duplicates brought the amount of records / rows down from 10,500 to 10,000. Then I removed white space and special characters from the dataset. After that, I identified and handled missing values in the dataset. I removed all of the rows that had missing data. Lastly, I cleaned the column names. In the original dataset, there were white spaces in the column names. There are now underscore characters where the white spaces used to be.

# %% [markdown]
# # Data Transformation

# %% [markdown]
# ## Creating / Renaming Columns

# %%
df1.rename(columns = {'patientage':'age', 'cityofresidence': 'city', 'stateofresidence': 'state', 'diseasediagnosed':'diagnosis', 'medicationprescribed': 'prescription', 'heightinkg': 'height_cm', 'weightinkg':'weight_kg'}, inplace = True)
df1
# Out:
# <ipython-input-38-04258c1b5236>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.rename(columns = {'patientage':'age', 'cityofresidence': 'city', 'stateofresidence': 'state', 'diseasediagnosed':'diagnosis', 'medicationprescribed': 'prescription', 'heightinkg': 'height_cm', 'weightinkg':'weight_kg'}, inplace = True)
#          age  gender              city         state hasinsurance  \
# 0       45.0   Other        West Brian      Kentucky          Yes
# 4       48.0  Female         Birdmouth       Montana           No
# 7       52.0    Male      Vanessaburgh   Connecticut          Yes
# 8       20.0  Female  West Briannabury       Montana           No
# 11      40.0  Female        Jonesmouth  Rhode Island           No
# ...      ...     ...               ...           ...          ...
# ...

# %% [markdown]
# ## Groupby and Summary Statistics

# %%
df1['diagnosis'].value_counts()
# Out:
# Cold        7228
# Flu         7185
# None        7162
# Allergy     7142
# Covid-19    7111
# Name: diagnosis, dtype: int64

# %%
grouped_data = df1.groupby('diagnosis').agg({
    'paymentdue': 'mean'
})
grouped_data
# Out:
#            paymentdue
# diagnosis
# Allergy    244.926193
# Cold       248.925305
# Covid-19   251.024933
# Flu        248.976765
# None       250.975049

# %% [markdown]
# ## Pivot Tables

# %%
pivot_data1 = df1.pivot_table(index='state', columns='diagnosis', values='paymentdue', aggfunc='mean')
pivot_data1
# Out:
# diagnosis          Allergy        Cold    Covid-19         Flu        None
# state
# Alabama         240.960786  248.609521  226.101461  251.667757  247.017729
# Alaska          246.874414  251.502446  263.664272  258.038319  243.456534
# Arizona         239.957722  237.236259  269.909130  239.960491  258.689307
# Arkansas        239.354558  259.014617  261.540967  238.783117  232.068658
# California      225.557059  251.017062  235.785484  264.382758  228.873362
# Colorado        240.164288  258.180106  250.533892  240.250736  238.313261
# Connecticut     245.811139  239.728018  260.657838  252.730255  275.573350
# Delaware        260.665090  239.882193  269.667932  265.985774  253.998159
# Florida         239.928960  245.346217  247.348811  246.702781  229.165361
# Georgia         221.306165  256.352908  255.095251  234.773001  265.681792
# Hawaii          236.692683  270.911307  255.748094  252.841528  242.855083
# ...

# %%
pivot_data2 = df1.pivot_table(index='prescription', columns='paymentmethod', values='prescriptioncost', aggfunc='mean')
pivot_data2
# Out:
# paymentmethod       Card       Cash  Insurance
# prescription
# Med_A          73.471973  75.994445  75.855721
# Med_B          75.208148  74.960271  74.756141
# Med_C          75.771138  76.048944  75.139967
# Med_D          73.942290  75.297394  74.939031
# Med_E          74.690713  75.606087  74.073754

# %%
pivot_data3 = df1.pivot_table(index='preferreddoctor', columns='typeofappointment', values='lastvisitdaysago', aggfunc='median')
pivot_data3
# Out:
# typeofappointment  Emergency  Follow-Up  General  Specialist
# preferreddoctor
# Dr. Brown              182.0      183.0    182.0       182.0
# Dr. Johnson            182.0      183.0    182.0       182.0
# Dr. Jones              183.0      182.0    183.0       183.0
# Dr. Smith              183.0      182.0    183.0       183.0
# Dr. Williams           182.0      183.0    183.0       182.0

# %% [markdown]
# # Introduction to Alternative Libraries

# %% [markdown]
# ##Polars

# %%
pip install polars

# %%
import polars as pl

df1 = pl.read_csv("healthcare_data_cleaning.csv")

print("Number of rows:", df1.shape[0])
print("Number of columns:", df1.shape[1])
# Out:
# Number of rows: 105000
# Number of columns: 20

# %%
import time

# %%
dataset_path = 'healthcare_data_cleaning.csv'

# %%
start_time = time.time()
polars_df = pd.read_csv(dataset_path)
polars_filtered = polars_df[polars_df['Gender'] == 'Female']
polars_average_age = polars_filtered['Average Heart Rate'].sum()
polars_time = time.time() - start_time

# %% [markdown]
# ## Load Times

# %%
print(f"Polars Execution Time: {polars_time:.4f} seconds")
# Out:
# Polars Execution Time: 0.5654 seconds

# %% [markdown]
# ### Load Times Observation
#
# I noticed that the execution time for Polars was 0.5654. I initially included Modin in my code and noticed that Modin was slower than Polar. I had to remove Modin from my code because it wouldn't work with the code that I used to change "missing" values into NaN values.
